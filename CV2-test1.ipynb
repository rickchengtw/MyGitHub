# %%
import cv2

# %%
import os

# %%
os.chdir('/Users/rick/Desktop/MyGitHub/images/')

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.imread('pandas_view_copy.png')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %%
os.chdir
